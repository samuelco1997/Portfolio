# %% [markdown]
# # Model Evaluations

# %% [markdown]
# ### Setup

# %%
# Setup
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import seaborn as sns
import statsmodels.api as sm
from plotnine import ggplot, aes, geom_point
from sklearn.tree import DecisionTreeClassifier
import xgboost as xgb
from xgboost import plot_importance
from xgboost import XGBRegressor
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MinMaxScaler

# %%
# Reading in preprocessed data
ipeds_clean = pd.read_csv("./ipeds_clean.csv")

# %% [markdown]
# ### Train-test splitting data

# %%
# Target variable: graduation rate (BA) within 4 years
X = ipeds_clean.drop(columns = ['Graduation rate - Bachelor degree within 4 years, total'])
y = ipeds_clean['Graduation rate - Bachelor degree within 4 years, total']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)

# %%
# Scaling features in dataframe
scaler = MinMaxScaler()
X_train_scaled = pd.DataFrame(scaler.fit_transform(X_train), columns=X_train.columns)
X_test_scaled = pd.DataFrame(scaler.fit_transform(X_test), columns=X_test.columns)

# %% [markdown]
# ## Defining function to fit untuned models

# %%
# defining function to evaluate and plot lasso regression models (untuned)
def evaluate_and_plot_model(model, x_train, y_train, x_test, y_test, model_name):
    model.fit(x_train, y_train)
    y_train_pred = model.predict(x_train)
    y_test_pred = model.predict(x_test)

    print(f"\n{model_name} Training Set Performance:")
    print("R-squared:", r2_score(y_train, y_train_pred))
    print("Mean Absolute Error (MAE):", mean_absolute_error(y_train, y_train_pred))
    print("Mean Squared Error (MSE):", mean_squared_error(y_train, y_train_pred))
    print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_train, y_train_pred)))

    print(f"\n{model_name} Test Set Performance:")
    print("R-squared:", r2_score(y_test, y_test_pred))
    print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_test_pred))
    print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_test_pred))
    print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test, y_test_pred)))

    plt.figure(figsize=(10, 6))
    #plt.scatter(y_test, y_test_pred, label=f'{model_name} Predictions')
    plt.scatter(y_test, y_test_pred, color='blue', alpha=0.5)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.title(f'{model_name} Predictions vs True Values')
    plt.legend()
    plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red') # Line for perfect predictions
    plt.show()

# %% [markdown]
# ## Model #1: Regression trees

# %% [markdown]
# ### Regression tree model, unpruned

# %%
# Evaluating and fitting model for preliminary (unpruned) regression tree
evaluate_and_plot_model(DecisionTreeRegressor(max_depth=5), X_train_scaled, y_train, X_test_scaled, y_test, "Regression tree")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Regression tree Training Set Performance:
# R-squared: 0.9576912649566355
# Mean Absolute Error (MAE): 3.4083191693697668
# Mean Squared Error (MSE): 20.214118571135508
# Root Mean Squared Error (RMSE): 4.49601140691786
#
# Regression tree Test Set Performance:
# R-squared: 0.8409647746339151
# Mean Absolute Error (MAE): 4.86467658435201
# Mean Squared Error (MSE): 63.178937859413146
# Root Mean Squared Error (RMSE): 7.948517966225726

# %%
# Cross validation: R2
from sklearn.model_selection import cross_val_score
cv_score = cross_val_score(regression_tree, X, y, cv=5, scoring='r2')
print("r2: ", cv_score)

# Cross validation: MSE
cv_score = cross_val_score(regression_tree, X, y, cv=5, scoring='neg_mean_squared_error')
print("Neg. MSE: ", cv_score)
# Out:
# r2:  [0.93644697 0.90667042 0.90704568 0.86683288 0.90804914]
# Neg. MSE:  [-34.41070221 -46.91603338 -58.31829442 -59.7003513  -36.41415734]

# %% [markdown]
# ### Regression tree, pruned

# %%
# Define hyperparameters grid
param_grid = {
    'max_depth': [3, 5, 7, 10],
    'min_samples_leaf': [1, 3, 5],
    'max_features' : [5, 10, 15, 'sqrt', 'log2', None],
    'ccp_alpha' : np.arange(0, 1, 0.01).tolist()
}

# Initialize DecisionTreeRegressor
regressor = DecisionTreeRegressor()

# Perform grid search cross-validation
grid_search = GridSearchCV(regressor, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_scaled, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Initialize DecisionTreeRegressor with the best hyperparameters
best_regressor = DecisionTreeRegressor(**best_params)

# Fit the model
best_regressor.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.42, max_depth=5, min_samples_leaf=5)

# %%
# Evaluating pruned regression tree
evaluate_and_plot_model(DecisionTreeRegressor(**best_params), X_train_scaled, y_train, X_test_scaled, y_test, "Regression tree")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Regression tree Training Set Performance:
# R-squared: 0.9544331492529612
# Mean Absolute Error (MAE): 3.5568632458575737
# Mean Squared Error (MSE): 21.770769628772843
# Root Mean Squared Error (RMSE): 4.665915733141014
#
# Regression tree Test Set Performance:
# R-squared: 0.8423135540723962
# Mean Absolute Error (MAE): 4.706512061802859
# Mean Squared Error (MSE): 62.64311661519698
# Root Mean Squared Error (RMSE): 7.914740464171707

# %% [markdown]
# ## Model #2: LASSO Regressions

# %% [markdown]
# ### LASSO regressions, untuned

# %%
# Evaluating untuned LASSO regressions
for alpha in [.01, .1, .5, 5]: 
    lasso = Lasso(alpha=alpha) # alpha will iterature through list above
    evaluate_and_plot_model(lasso, X_train_scaled, y_train, X_test_scaled, y_test, "Lasso Regression")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Lasso Regression Training Set Performance:
# R-squared: 0.9569700694421681
# Mean Absolute Error (MAE): 3.404254662782178
# Mean Squared Error (MSE): 20.558688826603394
# Root Mean Squared Error (RMSE): 4.534169033748454
#
# Lasso Regression Test Set Performance:
# R-squared: 0.8641907027894183
# Mean Absolute Error (MAE): 4.527509326919485
# Mean Squared Error (MSE): 53.95211739692795
# Root Mean Squared Error (RMSE): 7.345210507325706
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Lasso Regression Training Set Performance:
# R-squared: 0.948508526842635
# Mean Absolute Error (MAE): 3.743287815209609
# Mean Squared Error (MSE): 24.601414878950866
# Root Mean Squared Error (RMSE): 4.959981338568812
#
# Lasso Regression Test Set Performance:
# R-squared: 0.8650620852286464
# Mean Absolute Error (MAE): 4.321646991979732
# Mean Squared Error (MSE): 53.60594869843338
# Root Mean Squared Error (RMSE): 7.3216083409612525
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Lasso Regression Training Set Performance:
# R-squared: 0.9284020953397332
# Mean Absolute Error (MAE): 4.535944129321316
# Mean Squared Error (MSE): 34.207794980494775
# Root Mean Squared Error (RMSE): 5.848743025684645
#
# Lasso Regression Test Set Performance:
# R-squared: 0.8688953327381888
# Mean Absolute Error (MAE): 4.4527626886561285
# Mean Squared Error (MSE): 52.083138228943675
# Root Mean Squared Error (RMSE): 7.2168648476290365
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Lasso Regression Training Set Performance:
# R-squared: 0.0
# Mean Absolute Error (MAE): 18.18098202903112
# Mean Squared Error (MSE): 477.77648162765803
# Root Mean Squared Error (RMSE): 21.858098765163863
#
# Lasso Regression Test Set Performance:
# R-squared: -0.0007406328135735052
# Mean Absolute Error (MAE): 16.412395402728713
# Mean Squared Error (MSE): 397.5580259554355
# Root Mean Squared Error (RMSE): 19.93885718779879

# %%
# Cross validation
cv_score = cross_val_score(Lasso(alpha=0.01), X, y, cv=5, scoring='neg_mean_squared_error')
cv_score
# Out:
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.353e+04, tolerance: 4.890e+01
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.137e+04, tolerance: 4.929e+01
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.262e+04, tolerance: 5.134e+01
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.183e+04, tolerance: 5.076e+01
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.305e+04, tolerance: 5.197e+01
# array([-23.62677043, -40.63625012, -30.57749497, -34.52558521,
#        -26.20785423])

# %% [markdown]
# ### LASSO regressions, tuned

# %%
# Finding optimal parameters

# Define parameter grid
param_grid = {
    'alpha': np.arange(-10, 10, 5)  # Range of alpha values to search
}

# Initialize Lasso regression model
lasso = Lasso()

# Perform grid search cross-validation
grid_search = GridSearchCV(lasso, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_scaled, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Initialize Lasso regression with the best hyperparameters
best_lasso = Lasso(**best_params)

# Fit the model
best_lasso.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = best_lasso.predict(X_test_scaled)

# Calculate Mean Squared Error
print("R-squared:", r2_score(y_test, y_pred))
print("Mean Absolute Error (MAE):", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error (MSE):", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error (RMSE):", np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.886e+03, tolerance: 4.201e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.130e+03, tolerance: 4.071e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.685e+03, tolerance: 4.287e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.904e+03, tolerance: 4.199e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.286e+03, tolerance: 4.127e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 10 fits failed out of a total of 20.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 892, in fit
#     self._validate_params()
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Lasso must be a float in the range [0, inf). Got -10 instead.
#
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py", line 892, in fit
#     self._validate_params()
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\samue\anaconda4\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'alpha' parameter of Lasso must be a float in the range [0, inf). Got -5 instead.
#
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [          nan           nan  -26.48528856 -478.35551278]
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\model_selection\_search.py:909: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.037e+04, tolerance: 5.222e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# C:\Users\samue\AppData\Local\Temp\ipykernel_18568\3970044678.py:20: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# R-squared: 0.8692066837360966
# Mean Absolute Error (MAE): 4.482034240751544
# Mean Squared Error (MSE): 51.959449748583395
# Root Mean Squared Error (RMSE): 7.2082903485211665
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.037e+04, tolerance: 5.222e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.

# %%
# Evaluating and fitting tuned lASSO regression model
evaluate_and_plot_model(best_lasso, X_train_scaled, y_train, X_test_scaled, y_test, "Lasso Regression")
# Out:
# C:\Users\samue\AppData\Local\Temp\ipykernel_18568\439881147.py:3: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
# C:\Users\samue\anaconda4\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.037e+04, tolerance: 5.222e+01 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Lasso Regression Training Set Performance:
# R-squared: 0.9602816423840745
# Mean Absolute Error (MAE): 3.226557795383752
# Mean Squared Error (MSE): 18.976497157765944
# Root Mean Squared Error (RMSE): 4.3562021484047255
#
# Lasso Regression Test Set Performance:
# R-squared: 0.8692066837360966
# Mean Absolute Error (MAE): 4.482034240751544
# Mean Squared Error (MSE): 51.959449748583395
# Root Mean Squared Error (RMSE): 7.2082903485211665

# %%
# Feature importance
for i, importance in enumerate(best_lasso.coef_):
    print(f"Feature {i}: {importance}")
# Out:
# Feature 0: 4.952174427863766
# Feature 1: 1.1312446440033623
# Feature 2: 0.7437640638267577
# Feature 3: -7.850070724596892
# Feature 4: 1.5568207842289565
# Feature 5: 0.22664482039454079
# Feature 6: 2.6149289737213675
# Feature 7: 4.336056605189156
# Feature 8: 2.8164939510263673
# Feature 9: -4.653181092298517
# Feature 10: -5.809310758211428
# Feature 11: 5.530641569176583
# Feature 12: 2.746843024529421
# Feature 13: -4.8662119433225035
# Feature 14: -5.776987855731874
# Feature 15: -3.387163109582836
# Feature 16: 8.495615271320107
# Feature 17: -13.537450430426704
# Feature 18: 3.3855793232284594
# Feature 19: 0.49483400993568816
# Feature 229: 0.0
# Feature 230: 0.0
# Feature 231: 0.0
# Feature 232: 0.0
# Feature 233: 0.0
# Feature 234: 0.7287893880166273
# Feature 235: 0.0
# Feature 236: 0.0
# Feature 237: 0.0
# Feature 238: 0.0
# Feature 239: 0.0
# Feature 240: 0.0
# Feature 241: 0.0
# Feature 242: 0.0
# Feature 243: 0.0
# Feature 244: 0.0
# Feature 245: 0.0
# Feature 246: 0.0
# Feature 247: 1.7222742694085929
# Feature 248: 0.4382995240034266
# Feature 249: 1.3588784727982857
# Feature 250: 2.800466743544821
# Feature 251: 1.7888854525303506
# Feature 252: 0.0
# Feature 253: 2.1830464450164304
# Feature 254: 0.4623235459758542
# Feature 255: 0.0
# Feature 256: 1.062460347922766
# Feature 257: -9.833819984407395e-14

# %% [markdown]
# ## Model #3: XGBoost

# %% [markdown]
# ### XGBoost, untuned

# %%
# Evaluating and fitting untuned XGBoost regressor
evaluate_and_plot_model(XGBRegressor(), X_train_scaled, y_train, X_test_scaled, y_test, "XGBoost Regressor")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# XGBoost Regressor Training Set Performance:
# R-squared: 0.9999981008646063
# Mean Absolute Error (MAE): 0.02070455909432922
# Mean Squared Error (MSE): 0.0009073622265540482
# Root Mean Squared Error (RMSE): 0.030122453860103232
#
# XGBoost Regressor Test Set Performance:
# R-squared: 0.8693335587239347
# Mean Absolute Error (MAE): 4.036679496730331
# Mean Squared Error (MSE): 51.90904690887233
# Root Mean Squared Error (RMSE): 7.204793328671706

# %%
# Feature importance
importances = xgb_reg.feature_importances_

# Plot feature importances
plot_importance(xgb_reg)
plt.show()

# %% [markdown]
# ### XGBoost, tuned

# %%
# Initialize XGBoost regressor
xgb_reg = xgb.XGBRegressor(objective='reg:squarederror', random_state=10)

# Define parameter grid for pruning
param_grid = {
    'max_depth': [3, 4, 5, 6],
    'min_child_weight': [1, 2, 3, 4],
    'gamma': [0, 0.1, 0.2, 0.3],
    'subsample': [0.8, 0.9, 1.0],
    'colsample_bytree': [0.8, 0.9, 1.0]
}

# Perform grid search cross-validation
grid_search = GridSearchCV(estimator=xgb_reg, param_grid=param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train_scaled, y_train)

# Get the best hyperparameters
best_params = grid_search.best_params_

# Initialize XGBoost regressor with the best hyperparameters
best_xgb_reg = xgb.XGBRegressor(**best_params, objective='reg:squarederror', random_state=10)

# Fit the model
best_xgb_reg.fit(X_train_scaled, y_train)

# Predict on the test set
y_pred = best_xgb_reg.predict(X_test_scaled)

# Best parameters
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'colsample_bytree': 1.0, 'gamma': 0.3, 'max_depth': 5, 'min_child_weight': 2, 'subsample': 1.0}
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 33
#      30 print("Best Parameters:", best_params)
#      32 # Print evaluation metrics
# ---> 33 print("Mean Squared Error (MSE):", mse)
#      34 print("Root Mean Squared Error (RMSE):", rmse)
#      35 print("Mean Absolute Error (MAE):", mae)
#
# NameError: name 'mse' is not defined

# %%
# Evaluate and fitting tuned XGBoost model
evaluate_and_plot_model(best_xgb_reg, X_train_scaled, y_train, X_test_scaled, y_test, "XGBoost Regressor")
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# XGBoost Regressor Training Set Performance:
# R-squared: 0.9997508623867541
# Mean Absolute Error (MAE): 0.25605863746518076
# Mean Squared Error (MSE): 0.11903209229772738
# Root Mean Squared Error (RMSE): 0.34501027853924493
#
# XGBoost Regressor Test Set Performance:
# R-squared: 0.8641877960465232
# Mean Absolute Error (MAE): 4.070903659737023
# Mean Squared Error (MSE): 53.953272140654235
# Root Mean Squared Error (RMSE): 7.345289112121744
